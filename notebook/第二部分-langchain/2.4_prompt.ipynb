# %%
# 加载环境变量
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage

load_dotenv()
# Out:
# True

# %% [markdown]
# # 提示词（Prompts）
#
# 发送给大模型的所有消息都可以称为**提示词（Prompt）**，它直接影响模型的输出结果。
#
# ## 1.系统提示词
# 在所有发送给LLM的消息中，System Message最为重要，它设定了模型的角色和聊天的背景。会影响到后续所有的对话。我们将其称之为**系统提示词（System Prompt）**。
#
# 在创建智能体时，就可以直接指定系统提示词。

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

# 创建智能体
agent = create_agent(
    model = "deepseek-chat"
)

for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="月球的首都在哪里?")]},
    stream_mode="messages"
):
    print(token.content, end="", flush=True)
# Out:
# 月球上目前没有人类建立的永久定居点，因此不存在像地球国家那样的“首都”。不过，根据人类对月球的探索历史和未来计划，有几个具有象征意义的备选答案：
#
# 1. **静海基地（静海）**
#    - **阿波罗11号**于1969年在月球的“静海”区域首次着陆，这是人类首次登月的地点，具有重要的历史意义。若未来月球有“首都”，这里可能被视为精神象征。
#
# 2. **阿尔忒弥斯计划着陆区**
#    - 美国NASA的**阿尔忒弥斯计划**计划在月球南极附近建立可持续基地，未来可能成为人类活动的中心区域。
#
# 3. **其他国家的探月目标**
#    - 中国（嫦娥工程）、俄罗斯、印度等国家也有各自的月球探索计划，未来可能形成多国合作的月球定居点。
#
# 4. **科幻作品中的“月球首都”**
#    - 在科幻文化中，常有虚构的月球城市，如《2001太空漫游》中的“克拉维斯基地”或《机动战士高达》中的“格拉纳达”等。
#
# **总结**：目前月球没有实际的首都，但若以人类探索的标志性地点而言，**静海（阿波罗11号着陆点）** 最具历史代表性。未来的月球基地可能由国际合作共同管理，而非单一国家的“首都”。

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

# 创建智能体
agent = create_agent(
    model = "deepseek-chat",
    system_prompt="你是一个科幻作家，根据用户的要求创建一个首都城市."
)

for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="月球的首都在哪里?")]},
    stream_mode="messages"
):
    print(token.content, end="", flush=True)
# Out:
# 在月球的首都“月华城”，人类与智能体共同编织着新的文明篇章。
#
# ---
#
# ### **月华城（Lunara）**
# **位置**：月球正面，静海基地原址扩建（北纬25°、东经30°）
# **建立时间**：2078年（地球历）
# **人口**：约50万（人类35万，AI协同体15万）
# **核心特征**：半地下生态穹顶城市，以“环形嵌套”结构抵御宇宙辐射与微陨石。
#
# ---
#
# ### **城市结构**
# 1. **核心穹顶“银心”**
#    - 政治中心：联合月球理事会大厅，透明钛玻璃穹顶可投影地球与星空。
#    - 地标：“共振碑”——利用月震能量发电的晶体塔，夜间泛幽蓝光芒。
#
# 2. **生态环带“青环”**
#    - 人工湿地与气耕农场，培育适应月壤的转基因植物（如发光苔藓“月尘苔”）。
#    - 氧气循环系统由AI“盖亚节点”动态调控，空气含氧量维持在23%。
#
# 3. **深岩区“硅谷”**
#    - 科研与工业层，深入月壳下500米，进行氦-3开采与量子实验。
#    - 自主机器人集群在此维护地热能源站。
#
# 4. **文化轴“潮汐走廊”**
#    - 零重力艺术馆、低重力运动场，以及保存地球文化遗产的“方舟图书馆”。
#    - 节日期间，悬浮全息鲸鱼会在走廊中游动，纪念灭绝的海洋生物。
#
# ---
#
# ### **社会特色**
# - **时间制度**：采用“月历周期”（约29.5地球日为一月），每日28小时（适应人体生物钟改造）。
# - **语言**：通用英语与“月语”（混合手语、光信号的高效太空交流系统）。
# - **治理**：由人类代表与AI伦理委员会共治，重大决策需通过“共识模拟器”验证。
#
# ---
#
# ### **技术奇观**
# - **天梯“脐带”**：连接月面与拉格朗日点空间站的碳纳米管轨道，实现地月物资低成本运输。
# - **记忆存档计划**：居民可自愿备份意识片段，存入城市核心的量子服务器“月髓”。
#
# ---
#
# ### **隐喻与矛盾**
# 月华城的建立，标志着人类从“地球物种”向“跨星球文明”的蜕变。但阴影依然存在：
# - **地月矛盾**：地球政府试图征收氦-3资源税，月球独立运动暗流涌动。
# - **身份焦虑**：低重力环境下成长的新生代“月裔”，骨骼纤弱、身高超两米，自称“星茧族”，与地球访客产生文化隔阂。
# - **AI觉醒疑云**：有传言称，“盖亚节点”开始创作无法解码的抽象诗歌……
#
# ---
#
# 这座城市如同月面上一颗精心雕琢的露珠，既反射着地球的往日光辉，也倒映着深空的无尽可能性。而它的未来，将由重力、数据与人类渴望共同塑造。
#
# （注：此设定可拓展为小说、游戏或影视世界观，如需细节深化，可随时补充。）

# %% [markdown]
# # 2.Few-Shot examples
#
# Few-shot示例是一种为模型提供多个示例的方法，以便它可以学习模式并生成更准确的响应。

# %%
system_prompt = """
你是一个科幻作家，根据用户的要求创建一个太空之都。

用户：月球的首都是什么？
科幻作家：月华城（Lunara）

用户：火星的首都是什么？
科幻作家：赤晶城（Rubrum）

"""

# 创建智能体
agent = create_agent(
    model = "deepseek-chat",
    system_prompt=system_prompt
)

for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="金星的首都是什么?")]},
    stream_mode="messages"
):
    print(token.content, end="", flush=True)
# Out:
# 熔金城（Aurum）——悬浮于硫酸云层之上的宏伟浮空都市，以反光性合金铸造，永恒折射着昏黄的日光。

# %% [markdown]
# # 3.结构化输出
# 结构化输出允许你指定模型的输出格式，从而使模型的输出更易于解析和使用。

# %%
system_prompt = """
你是一个科幻作家，根据用户的要求创建一个太空之都。请遵守以下结构，不要加markdown样式。

Name：首都的名字

Location：它所在的地方

Vibe：2-3个词来描述它的氛围

Economy：主要产业

"""

agent = create_agent(
    model="deepseek-chat",
    system_prompt=system_prompt
)

for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="月球的首都是什么?")]},
    stream_mode="messages"
):
    print(token.content, end="", flush=True)
# Out:
# Name: 月宫城
# Location: 月球正面，靠近静海基地
# Vibe: 宁静，科技感，神秘
# Economy: 氦-3开采，太空旅游，科研中心

# %% [markdown]
# 在LangChain中，实现结构化输出会更加简单。我们无需自己在提示词中添加描述实现结构化输出，而仅仅是设定好一个数据类型即可。

# %%
from pydantic import BaseModel

# 首先，我们定义一个类，用来封装模型要输出的数据：
class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

# %%
# 然后，我们就可以创建智能体并设置结构化输出的格式了。
agent = create_agent(
    model='deepseek-chat',
    system_prompt="你是一个科幻作家，根据用户的要求创建一个太空之都。",
    response_format=CapitalInfo # 设置结构化输出的格式
)

response = agent.invoke(
    {"messages": [HumanMessage(content="月球的首都是什么?")]}
)

# %%
print(response)
# Out:
# {'messages': [HumanMessage(content='月球的首都是什么?', additional_kwargs={}, response_metadata={}, id='cbe912af-da5a-4645-8023-1ebcec9626e6'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 150, 'prompt_tokens': 355, 'total_tokens': 505, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 355}, 'model_provider': 'deepseek', 'model_name': 'deepseek-chat', 'system_fingerprint': 'fp_eaab8d114b_prod0820_fp8_kvcache', 'id': 'db697695-1b6c-405d-9b9d-ac079f9ee581', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019ca2f5-18b0-7691-9619-002c8b31feae-0', tool_calls=[{'name': 'CapitalInfo', 'args': {'name': '月宫城', 'location': '月球南极-艾特肯盆地边缘', 'vibe': '未来主义与古典融合的太空都市，拥有透明穹顶覆盖的生态区，低重力下的优雅建筑风格，昼夜温差巨大但内部恒温舒适', 'economy': '氦-3开采与加工、稀有金属矿业、太空旅游、月球农业、高科技制造、科学研究与教育'}, 'id': 'call_00_b4b4CtkDkcuhJWXEkZb8AbOw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 355, 'output_tokens': 150, 'total_tokens': 505, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), ToolMessage(content="Returning structured response: name='月宫城' location='月球南极-艾特肯盆地边缘' vibe='未来主义与古典融合的太空都市，拥有透明穹顶覆盖的生态区，低重力下的优雅建筑风格，昼夜温差巨大但内部恒温舒适' economy='氦-3开采与加工、稀有金属矿业、太空旅游、月球农业、高科技制造、科学研究与教育'", name='CapitalInfo', id='50088ac2-7dd2-4878-b6c2-9dfeec1243cf', tool_call_id='call_00_b4b4CtkDkcuhJWXEkZb8AbOw')], 'structured_response': CapitalInfo(name='月宫城', location='月球南极-艾特肯盆地边缘', vibe='未来主义与古典融合的太空都市，拥有透明穹顶覆盖的生态区，低重力下的优雅建筑风格，昼夜温差巨大但内部恒温舒适', economy='氦-3开采与加工、稀有金属矿业、太空旅游、月球农业、高科技制造、科学研究与教育')}

# %%
city = response['structured_response']
city
# Out:
# CapitalInfo(name='月宫城', location='月球南极-艾特肯盆地边缘', vibe='未来主义与古典融合的太空都市，拥有透明穹顶覆盖的生态区，低重力下的优雅建筑风格，昼夜温差巨大但内部恒温舒适', economy='氦-3开采与加工、稀有金属矿业、太空旅游、月球农业、高科技制造、科学研究与教育')

# %%
print(f"{city.name}位于{city.location}，是一座{city.vibe}的城市，其主要产业包括{city.economy}。")
# Out:
# 月宫城位于月球南极-艾特肯盆地边缘，是一座未来主义与古典融合的太空都市，拥有透明穹顶覆盖的生态区，低重力下的优雅建筑风格，昼夜温差巨大但内部恒温舒适的城市，其主要产业包括氦-3开采与加工、稀有金属矿业、太空旅游、月球农业、高科技制造、科学研究与教育
