# %% [markdown]
# # OpenAI 调用大模型
#
# ## 0.准备工作
#
# 首先，我们需要安装OpenAI的依赖
# 安装命令：
# ```shell
# uv add openai
# ```

# %% [markdown]
# ## 1.初始化客户端
#
# ### 1.1.硬编码API_KEY

# %%
from openai import OpenAI

# 创建 OpenAI 客户端
client = OpenAI(
    api_key="sk-d37641d8e49c4bf8993677d9c681b241",
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
)

# %% [markdown]
# ### 1.2. 从环境变量中获取API_KEY

# %% [markdown]
# 读取环境变量需要用到python-dotenv，先安装依赖
# 安装命令：
# ```shell
# uv add python-dotenv
# ```
# 再创建.env文件，并写入api_key
# ```properties
# DASHSCOPE_API_KEY=sk-d37641d8e49c4bf8993677d9c681b241
# ```
# 接着就可以可以从环境变量中获取api_key了

# %%
from dotenv import load_dotenv
import os

#加载到环境变量
load_dotenv()

api_key = os.getenv("DASHSCOPE_API_KEY")
print(api_key)

client = OpenAI(
    api_key=api_key,
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1"
)
# Out:
# sk-d37641d8e49c4bf8993677d9c681b241

# %% [markdown]
# ## 2.访问模型

# %%
print("🚀 正在调用大模型...")
response = client.chat.completions.create(
    model="deepseek-v4-pro",
    messages=[
        {"role": "system", "content": "你是一名友好的AI助教。"},
        {"role": "user", "content": "你好，你是谁?"}
    ],
    stream=False,
    temperature=0.9,
)
print("🚀 成功调用大模型...")
# Out:
# 🚀 正在调用大模型...
# 🚀 成功调用大模型...

# %% [markdown]
# ## 3.获取模型响应结果

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-6bdefef2-6785-9f2f-b8df-cd65d2faa9cb",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "你好！我是一名友好的AI助教，可以为你解答学习上的问题、帮助理解复杂的概念、提供学习建议，或者一起探讨你感兴趣的知识。\n\n无论你需要什么帮助，都可以随时告诉我。让我们一起开始学习吧！你有什么想问的吗？😊",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": null,
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null,
#         "reasoning_content": "嗯，用户用中文打招呼并询问我的身份。\n\n这是一个非常简单的自我介绍问题。我需要清晰地说明我是谁、我的功能和特点，同时保持友好和乐于助人的态度。\n\n我可以直接说明我是AI助教，并简要介绍我的主要功能和友好、耐心的特点，最后以开放式的提问结束，引导用户提出需求。这样既回答了问题，又促进了对话的继续。"
#       }
#     }
#   ],
#   "created": 1777387682,
#   "model": "deepseek-v4-pro",
#   "object": "chat.completion",
#   "service_tier": null,
#   "system_fingerprint": null,
#   "usage": {
#     "completion_tokens": 132,
#     "prompt_tokens": 15,
#     "total_tokens": 147,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": null,
#       "audio_tokens": null,
#       "reasoning_tokens": 78,
#       "rejected_prediction_tokens": null
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": null,
#       "cached_tokens": 0
#     }
#   }
# }

# %%
print(response.choices[0].message.content)
# Out:
# 你好！我是一名友好的AI助教，可以为你解答学习上的问题、帮助理解复杂的概念、提供学习建议，或者一起探讨你感兴趣的知识。
#
# 无论你需要什么帮助，都可以随时告诉我。让我们一起开始学习吧！你有什么想问的吗？😊
